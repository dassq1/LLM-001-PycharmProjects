# %%
import torch
import torch.nn as nn

# %%
rnn=nn.RNN(
    input_size=5,
    hidden_size=3,
    batch_first=True,
)
x=torch.randn(2,3,5)
x.shape
# Out:
# torch.Size([2, 3, 5])

# %%
output,hidden=rnn(x)

# %%
print(x.shape)
# Out:
# torch.Size([2, 3, 5])

# %%
print(output.shape)
# Out:
# torch.Size([2, 3, 3])

# %%
print(hidden.shape)
# Out:
# torch.Size([1, 2, 3])

# %%
hidden
# Out:
# tensor([[[-0.9039, -0.9175, -0.4584],
#          [ 0.1059, -0.1635,  0.6983]]], grad_fn=<StackBackward0>)
