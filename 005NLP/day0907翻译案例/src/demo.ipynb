# %%
import torch
from torch import nn

# %%
embedding=nn.Embedding(
    num_embeddings=10,# 词表长度
    embedding_dim=4
)

# %%
x=torch.tensor([
    [1,2,3],
    [4,5,6],
])

# %%
print(x)
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
y=embedding(x)
print(y)
# Out:
# tensor([[[-0.2717,  1.7482,  1.9832, -1.5947],
#          [-1.7004, -0.3863, -0.2143, -1.1930],
#          [ 0.3639, -0.8081, -0.3154, -0.6517]],
#
#         [[ 0.9818,  0.4490,  1.9741,  1.9872],
#          [-1.5787,  1.3106,  1.4611, -0.1129],
#          [ 0.7056, -2.0446, -0.2911, -1.9057]]], grad_fn=<EmbeddingBackward0>)

# %%
print(y.shape)
# Out:
# torch.Size([2, 3, 4])
