# %%
import torch

# %%
x = torch.tensor([1, 2, 3])

print(x.device)
# Out:
# cpu

# %%
x=torch.tensor([10,20,30,40,50])
x
# Out:
# tensor([10, 20, 30, 40, 50])

# %%
x[1:4]
# Out:
# tensor([20, 30, 40])

# %%
import torch
a = torch.randn(2, 3)      # 形状 (2, 3)
b = torch.randn(2, 3, 2)   # 形状 (2, 3, 2)
c = a @ b
print(c.shape)  # 输出: torch.Size([2, 2, 2])
# Out:
# torch.Size([2, 2, 2])
