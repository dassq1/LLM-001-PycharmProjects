# %%
from sklearn.linear_model import LogisticRegression

# %%
# 构造方法
model =LogisticRegression(
    penalty='L1',
    solver='liblinear',
    multi_class='ovr',
    C=0.5,
    class_weight='balanced',
)
