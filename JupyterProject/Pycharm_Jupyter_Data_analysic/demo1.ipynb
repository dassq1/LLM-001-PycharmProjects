# %%
import numpy as np
import pandas as pd
# !python --version
# Out:
# Python 3.14.6

# %%
import sys
print(sys.version)
print(sys.version_info)
# Out:
# 3.12.13 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:26:47) [MSC v.1942 64 bit (AMD64)]
# sys.version_info(major=3, minor=12, micro=13, releaselevel='final', serial=0)

# %% [markdown]
# # 测试练习

# %%
print("666")
# Out:
# 666

# %%
arr1=np.matrix("1 2;3 4")
arr1
# Out:
# matrix([[1, 2],
#         [3, 4]])

# %%
arr2=np.matrix([[1,2],[3,4]])
print(arr2)
# Out:
# [[1 2]
#  [3 4]]

# %%
pd.Series(data={"a":1,"b":2,"c":3,"d":4,"e":5})
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
