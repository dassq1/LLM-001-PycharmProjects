# %%
import pandas as pd

# %%
df=pd.read_csv("data/sleep.csv")
df.head()
# Out:
#    person_id  gender  age     occupation  sleep_duration  sleep_quality  \
# 0          1    Male   29   Manual Labor             7.4            7.0
# 1          2  Female   43        Retired             4.2            4.9
# 2          3    Male   44        Retired             6.1            6.0
# 3          4    Male   29  Office Worker             8.3           10.0
# 4          5    Male   67        Retired             9.1            9.5
#
#    physical_activity_level  stress_level bmi_category blood_pressure  \
# 0                       41             7        Obese         124/70
# 1                       41             5        Obese         131/86
# 2                      107             4  Underweight         122/70
# 3                       20            10        Obese         124/72
# 4                       19             4   Overweight         133/78
#
#    heart_rate  daily_steps sleep_disorder
# 0          91         8539            NaN
# 1          81        18754            NaN
# 2          81         2857            NaN
# 3          55         6886            NaN
# 4          97        14945       Insomnia

# %%
df.dtypes
# Out:
# person_id                    int64
# gender                         str
# age                          int64
# occupation                     str
# sleep_duration             float64
# sleep_quality              float64
# physical_activity_level      int64
# stress_level                 int64
# bmi_category                   str
# blood_pressure                 str
# heart_rate                   int64
# daily_steps                  int64
# sleep_disorder                 str
# dtype: object

# %%
df['age']=df['age'].astype('int16')
df.dtypes
# Out:
# person_id                    int64
# gender                         str
# age                          int16
# occupation                     str
# sleep_duration             float64
# sleep_quality              float64
# physical_activity_level      int64
# stress_level                 int64
# bmi_category                   str
# blood_pressure                 str
# heart_rate                   int64
# daily_steps                  int64
# sleep_disorder                 str
# dtype: object

# %%
df['gender']=df['gender'].astype('category')
df.dtypes
# Out:
# person_id                     int64
# gender                     category
# age                           int16
# occupation                      str
# sleep_duration              float64
# sleep_quality               float64
# physical_activity_level       int64
# stress_level                  int64
# bmi_category                    str
# blood_pressure                  str
# heart_rate                    int64
# daily_steps                   int64
# sleep_disorder                  str
# dtype: object

# %%
import numpy as np

# %%
df.T
# Out:
#                                   0        1            2              3    \
# person_id                           1        2            3              4
# gender                           Male   Female         Male           Male
# age                                29       43           44             29
# occupation               Manual Labor  Retired      Retired  Office Worker
# sleep_duration                    7.4      4.2          6.1            8.3
# sleep_quality                     7.0      4.9          6.0           10.0
# physical_activity_level            41       41          107             20
# stress_level                        7        5            4             10
# bmi_category                    Obese    Obese  Underweight          Obese
# blood_pressure                 124/70   131/86       122/70         124/72
# heart_rate                         91       81           81             55
# daily_steps                      8539    18754         2857           6886
# sleep_disorder                    NaN      NaN          NaN            NaN
#
#                                 4        5              6              7    \
# person_id                         5        6              7              8
# gender                         Male   Female           Male           Male
# age                              67       47             22             49
# occupation                  Retired  Student  Office Worker  Office Worker
# sleep_duration                  9.1      6.1            5.1           10.7
# sleep_quality                   9.5      6.9            6.1            6.2
# physical_activity_level          19       24             26             49
# stress_level                      4        4              6              8
# bmi_category             Overweight   Normal          Obese          Obese
# blood_pressure               133/78   123/60         121/70         134/87
# heart_rate                       97       87             66             59
# daily_steps                   14945     9485          15680          18767
# sleep_disorder             Insomnia      NaN            NaN            NaN
#
#                                   8           9    ...      390  \
# person_id                           9          10  ...      391
# gender                           Male      Female  ...     Male
# age                                25          51  ...       47
# occupation               Manual Labor     Retired  ...  Retired
# sleep_duration                   11.9         8.2  ...      7.6
# sleep_quality                     7.2         4.0  ...      8.7
# physical_activity_level            27          64  ...       47
# stress_level                        8           5  ...       10
# bmi_category              Underweight  Overweight  ...   Normal
# blood_pressure                 112/63      125/84  ...   123/68
# heart_rate                         99          76  ...       79
# daily_steps                     16397       12744  ...     8226
# sleep_disorder            Sleep Apnea         NaN  ...      NaN
#
#                                    391           392           393       394  \
# person_id                          392           393           394       395
# gender                            Male        Female        Female      Male
# age                                 61            18            28        48
# occupation               Office Worker  Manual Labor  Manual Labor   Retired
# sleep_duration                     9.1           8.2           9.9       4.7
# sleep_quality                      7.1           6.9          10.0       4.7
# physical_activity_level             69            68            19       108
# stress_level                         2             3             3         9
# bmi_category                    Normal        Normal         Obese     Obese
# blood_pressure                  130/75        109/61        124/75    134/92
# heart_rate                          61            59            93        60
# daily_steps                      16330          6891          6992      3961
# sleep_disorder                Insomnia      Insomnia           NaN  Insomnia
#
#                                  395           396       397          398  \
# person_id                        396           397       398          399
# gender                        Female        Female    Female       Female
# age                               36            45        30           41
# occupation                   Student  Manual Labor   Student      Retired
# sleep_duration                   4.5           6.0       5.3         11.0
# sleep_quality                    7.9           6.1       6.5          9.1
# physical_activity_level           73            72        58           73
# stress_level                       7             8        10            9
# bmi_category                  Normal         Obese     Obese        Obese
# blood_pressure                118/66        132/80    125/76       130/75
# heart_rate                        64            65        66           75
# daily_steps                    14497         12848     15255         6567
# sleep_disorder           Sleep Apnea      Insomnia  Insomnia  Sleep Apnea
#
#                              399
# person_id                    400
# gender                      Male
# age                           37
# occupation               Retired
# sleep_duration               5.8
# sleep_quality                7.0
# physical_activity_level       41
# stress_level                   6
# bmi_category              Normal
# blood_pressure            118/70
# heart_rate                    51
# daily_steps                18079
# sleep_disorder               NaN
#
# [13 rows x 400 columns]

# %%
df.head()
# Out:
#    person_id  gender  age     occupation  sleep_duration  sleep_quality  \
# 0          1    Male   29   Manual Labor             7.4            7.0
# 1          2  Female   43        Retired             4.2            4.9
# 2          3    Male   44        Retired             6.1            6.0
# 3          4    Male   29  Office Worker             8.3           10.0
# 4          5    Male   67        Retired             9.1            9.5
#
#    physical_activity_level  stress_level bmi_category blood_pressure  \
# 0                       41             7        Obese         124/70
# 1                       41             5        Obese         131/86
# 2                      107             4  Underweight         122/70
# 3                       20            10        Obese         124/72
# 4                       19             4   Overweight         133/78
#
#    heart_rate  daily_steps sleep_disorder
# 0          91         8539            NaN
# 1          81        18754            NaN
# 2          81         2857            NaN
# 3          55         6886            NaN
# 4          97        14945       Insomnia

# %%
df=pd.read_csv("data/sleep.csv")
df.head()
# Out:
#    person_id  gender  age     occupation  sleep_duration  sleep_quality  \
# 0          1    Male   29   Manual Labor             7.4            7.0
# 1          2  Female   43        Retired             4.2            4.9
# 2          3    Male   44        Retired             6.1            6.0
# 3          4    Male   29  Office Worker             8.3           10.0
# 4          5    Male   67        Retired             9.1            9.5
#
#    physical_activity_level  stress_level bmi_category blood_pressure  \
# 0                       41             7        Obese         124/70
# 1                       41             5        Obese         131/86
# 2                      107             4  Underweight         122/70
# 3                       20            10        Obese         124/72
# 4                       19             4   Overweight         133/78
#
#    heart_rate  daily_steps sleep_disorder
# 0          91         8539            NaN
# 1          81        18754            NaN
# 2          81         2857            NaN
# 3          55         6886            NaN
# 4          97        14945       Insomnia

# %%
df=df[['person_id','blood_pressure']]
df.head()
# Out:
#    person_id blood_pressure
# 0          1         124/70
# 1          2         131/86
# 2          3         122/70
# 3          4         124/72
# 4          5         133/78

# %%
type(['blood_pressure'])
# Out:
# list

# %%
df['blood_pressure'].str.split('/',expand=True)
# Out:
#        0   1
# 0    124  70
# 1    131  86
# 2    122  70
# 3    124  72
# 4    133  78
# ..   ...  ..
# 395  118  66
# 396  132  80
# 397  125  76
# 398  130  75
# 399  118  70
#
# [400 rows x 2 columns]

# %%
df[['high','low']]=df['blood_pressure'].str.split('/',expand=True)
df
# Out:
#      person_id blood_pressure high low
# 0            1         124/70  124  70
# 1            2         131/86  131  86
# 2            3         122/70  122  70
# 3            4         124/72  124  72
# 4            5         133/78  133  78
# ..         ...            ...  ...  ..
# 395        396         118/66  118  66
# 396        397         132/80  132  80
# 397        398         125/76  125  76
# 398        399         130/75  130  75
# 399        400         118/70  118  70
#
# [400 rows x 4 columns]

# %%
df.dtypes
# Out:
# person_id         int64
# blood_pressure      str
# high                str
# low                 str
# dtype: object

# %%
df['high']=df['high'].astype('int64')
df['low']=df['low'].astype('int64')

# %%
df.dtypes
# Out:
# person_id         int64
# blood_pressure      str
# high              int64
# low               int64
# dtype: object

# %% [markdown]
# # 数据分箱

# %%
import  pandas as pd

# %%
df=pd.read_csv("data/employees.csv")

# %%
df1=df.head(10)[['employee_id','salary']]
print(df1['salary'].min())
print(df1['salary'].max())
# Out:
# 4200.0
# 24000.0

# %%
pd.cut(df1['salary'],bins=2)
# Out:
# 0    (14100.0, 24000.0]
# 1    (14100.0, 24000.0]
# 2    (14100.0, 24000.0]
# 3     (4180.2, 14100.0]
# 4     (4180.2, 14100.0]
# 5     (4180.2, 14100.0]
# 6     (4180.2, 14100.0]
# 7     (4180.2, 14100.0]
# 8     (4180.2, 14100.0]
# 9     (4180.2, 14100.0]
# Name: salary, dtype: category
# Categories (2, interval[float64, right]): [(4180.2, 14100.0] < (14100.0, 24000.0]]

# %%
pd.qcut(df1['salary'],3).value_counts()
# Out:
# salary
# (4199.999, 6000.0]    4
# (6000.0, 12000.0]     3
# (12000.0, 24000.0]    3
# Name: count, dtype: int64
