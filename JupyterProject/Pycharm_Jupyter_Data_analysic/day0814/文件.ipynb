# %%
import pandas as pd
import pymysql
import numpy as np

# %%
# conn=pymysql.connect(
#     host="localhost",
#     user="root",
#     password="12345",
#     database="atguigu",
#     charset="utf8mb4"
# )

# %%
sql= "show tables"
df=pd.read_sql(sql,conn)
print(df)
# Out:
#   Tables_in_atguigu
# 0            person
# 1           person1
# 2      t_department
# 3            t_emp3
# 4        t_employee
# 5             t_job
# 6          t_person
# C:\Users\23716\AppData\Local\Temp\ipykernel_21680\29961441.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(sql,conn)

# %%
sql1="select * from t_employee"
df=pd.read_sql(sql,conn)
print(df)
# Out:
#   Tables_in_atguigu
# 0            person
# 1           person1
# 2      t_department
# 3            t_emp3
# 4        t_employee
# 5             t_job
# 6          t_person
# C:\Users\23716\AppData\Local\Temp\ipykernel_21680\32934347.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(sql,conn)

# %%
from sqlalchemy import create_engine
engine=create_engine(
    "mysql+pymysql://root:12345@localhost:3306/atguigu?charset=utf8mb4"
)

# %%
sql="select * from t_employee"
df=pd.read_sql(sql,engine)
print(df)
# Out:
#     eid ename   salary  commission_pct    birthday gender          tel  \
# 0     1   孙洪亮  28000.0            0.65  1980-10-08      男  13789098765
# 1     2    何进   7001.0            0.10  1984-08-03      男  13456732145
# 2     3   邓超远   8000.0             NaN  1985-04-09      男  18678973456
# 3     4   黄熙萌   9456.0             NaN  1986-09-07      女  13609876789
# 4     5    陈浩   8567.0             NaN  1978-08-02      男  13409876545
# 5     6   韩庚年  12000.0             NaN  1985-04-03      男  18945678986
# 6     7   贾宝玉  15700.0            0.24  1982-08-02      男  15490876789
# 7     8   李晨熙   9000.0            0.40  1983-03-02      女  13587689098
# 8     9   李易峰   7897.0             NaN  1984-09-01      男  13467676789
# 9    10    陆风   8789.0             NaN  1989-04-02      男  13689876789
# 10   11   黄冰茹  15678.0             NaN  1983-05-07      女  13787876565
# 11   12   孙红梅   9000.0             NaN  1986-04-02      女  13576234554
# 12   13   李冰冰  18760.0             NaN  1987-04-09      女  13790909887
# 13   14   谢吉娜  18978.0            0.25  1990-01-01      女  13234543245
# 14   15   董吉祥   8978.0             NaN  1987-05-05      男  13876544333
# 15   16   彭超越   9878.0             NaN  1988-03-06      男  18264578930
# 16   17   李诗雨   9000.0             NaN  1990-08-09      女  18567899098
# 17   18   舒淇格  16788.0            0.10  1978-09-04      女  18654565634
# 18   19   周旭飞   7876.0             NaN  1988-06-13      女  13589893434
# 19   20   章嘉怡  15099.0            0.10  1989-12-11      女  15634238979
# 20   21    白露   9787.0             NaN  1989-09-04      女  18909876789
# 21   22    刘烨  13099.0            0.32  1990-11-09      男  18890980989
# 22   23    陈纲  13090.0             NaN  1990-02-04      男  18712345632
# 23   24  吉日格勒  10289.0             NaN  1990-04-01      男  17290876543
# 24   25  额日古那   9087.0             NaN  1989-08-01      女  18709675645
# 25   26    李红   5000.0             NaN  1995-02-15      女  15985759663
# 26   27    周洲   8000.0             NaN  1990-01-01      男  13574528569
#
#                    email address   work_place    hiredate  job_id   mid  did
# 0        shl@atguigu.com   白庙村西街        北京,深圳  2011-07-28     1.0   NaN  1.0
# 1         hj@atguigu.com    半截塔存        深圳,上海  2015-07-03     2.0   1.0  1.0
# 2     dcy666@atguigu.com     宏福苑  北京,深圳,上海,武汉  2014-07-01     3.0   7.0  1.0
# 3        hxm@atguigu.com   白庙村东街     深圳,上海,武汉  2015-08-08     8.0  22.0  3.0
# 4      ch888@atguigu.com     回龙观     北京,深圳,上海  2015-01-01     3.0   3.0  1.0
# 5        hgn@atguigu.com      龙泽        深圳,上海  2015-02-02     3.0   2.0  1.0
# 6        jby@atguigu.com      霍营        北京,武汉  2015-03-03     2.0   1.0  1.0
# 7         lc@atguigu.com     东三旗     深圳,上海,武汉  2015-01-06     4.0   1.0  1.0
# 8        lyf@atguigu.com     西山旗           武汉  2015-04-01     3.0   7.0  1.0
# 9         lf@atguigu.com   天通苑一区           北京  2014-09-03     2.0   1.0  1.0
# 10       hbr@atguigu.com     立水桥           深圳  2014-04-04     4.0   1.0  1.0
# 11       shm@atguigu.com     立城苑           上海  2014-02-08     3.0   7.0  1.0
# 12       lbb@atguigu.com  王府温馨公寓           北京  2015-06-07     3.0   2.0  1.0
# 13       xjn@atguigu.com     园中园        上海,武汉  2015-09-05     5.0   1.0  2.0
# 14       djx@atguigu.com     小辛庄        北京,上海  2015-08-04     6.0  14.0  2.0
# 15       pcy@atguigu.com     西二旗        深圳,武汉  2015-03-06     8.0  22.0  3.0
# 16       lsy@atguigu.com      清河     北京,深圳,武汉  2013-06-09     8.0  22.0  3.0
# 17       sqg@atguigu.com    名流花园     北京,深圳,武汉  2013-04-05     9.0   1.0  4.0
# 18       sxf@atguigu.com     小汤山        北京,深圳  2014-04-07    10.0  18.0  4.0
# 19       zjy@atguigu.com    望都家园           北京  2015-08-04    11.0   1.0  5.0
# 20        bl@atguigu.com    西湖新村           上海  2014-06-05    12.0  20.0  5.0
# 21        ly@atguigu.com    多彩公寓        北京,上海  2016-08-09     7.0   1.0  3.0
# 22        cg@atguigu.com   天通苑二区           深圳  2016-05-09     3.0   2.0  1.0
# 23          jrgl@163.com      北苑           北京  2017-02-06    12.0  20.0  5.0
# 24      ergn@atguigu.com      望京        北京,上海  2017-09-01     3.0   2.0  1.0
# 25    lihong@atguigu.com     冠雅苑           北京  2021-09-01     NaN   NaN  NaN
# 26  zhouzhou@atguigu.com     冠华苑        北京,深圳  2020-08-15     3.0   2.0  NaN
