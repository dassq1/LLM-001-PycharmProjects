# %%
import pandas as pd
df = pd.DataFrame({"gmv":[100,200,300,400],"trade_date":["2025-01-06","2023-10-31","2023-12-31","2023-01-05"]})

# %%
print(df)
# Out:
#    gmv  trade_date
# 0  100  2025-01-06
# 1  200  2023-10-31
# 2  300  2023-12-31
# 3  400  2023-01-05

# %%
df['ymd']=pd.to_datetime(df['trade_date'])
print(df)
# Out:
#    gmv  trade_date        ymd
# 0  100  2025-01-06 2025-01-06
# 1  200  2023-10-31 2023-10-31
# 2  300  2023-12-31 2023-12-31
# 3  400  2023-01-05 2023-01-05

# %%
df['yy']=df['ymd'].dt.year
df['mm']=df['ymd'].dt.month
df['dd']=df['ymd'].dt.day
print(df)
# Out:
#    gmv  trade_date        ymd    yy  mm  dd
# 0  100  2025-01-06 2025-01-06  2025   1   6
# 1  200  2023-10-31 2023-10-31  2023  10  31
# 2  300  2023-12-31 2023-12-31  2023  12  31
# 3  400  2023-01-05 2023-01-05  2023   1   5

# %%
df['week']=df['ymd'].dt.day_name()

print(df)
# Out:
#    gmv  trade_date        ymd    yy  mm  dd      week  quarter
# 0  100  2025-01-06 2025-01-06  2025   1   6    Monday        1
# 1  200  2023-10-31 2023-10-31  2023  10  31   Tuesday        4
# 2  300  2023-12-31 2023-12-31  2023  12  31    Sunday        4
# 3  400  2023-01-05 2023-01-05  2023   1   5  Thursday        1

# %%
df['quarter']=df['ymd'].dt.quarter
print(df)
# Out:
#    gmv  trade_date        ymd    yy  mm  dd      week  quarter
# 0  100  2025-01-06 2025-01-06  2025   1   6    Monday        1
# 1  200  2023-10-31 2023-10-31  2023  10  31   Tuesday        4
# 2  300  2023-12-31 2023-12-31  2023  12  31    Sunday        4
# 3  400  2023-01-05 2023-01-05  2023   1   5  Thursday        1

# %%
df['ystst']=df['ymd'].dt.to_period("Y")
print(df)
# Out:
#    gmv  trade_date        ymd    yy  mm  dd      week  quarter ystst
# 0  100  2025-01-06 2025-01-06  2025   1   6    Monday        1  2025
# 1  200  2023-10-31 2023-10-31  2023  10  31   Tuesday        4  2023
# 2  300  2023-12-31 2023-12-31  2023  12  31    Sunday        4  2023
# 3  400  2023-01-05 2023-01-05  2023   1   5  Thursday        1  2023

# %%
df['mstst']=df['ymd'].dt.to_period("M")
print(df)
# Out:
#    gmv  trade_date        ymd    yy  mm  dd      week  quarter ystst    mstst
# 0  100  2025-01-06 2025-01-06  2025   1   6    Monday        1  2025  2025-01
# 1  200  2023-10-31 2023-10-31  2023  10  31   Tuesday        4  2023  2023-10
# 2  300  2023-12-31 2023-12-31  2023  12  31    Sunday        4  2023  2023-12
# 3  400  2023-01-05 2023-01-05  2023   1   5  Thursday        1  2023  2023-01
