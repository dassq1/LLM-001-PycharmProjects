# %%
#
# 1. 创建一个3*4的二维数组，并用[1,5]的随机整数进行填充
#    取出上述创建数组的 前两行后三列 切片
import numpy as np
import pandas as pd
arr1=np.random.randint(1,6,(3,4))
arr1
arr1[0:2,1:4]
# Out:
# array([[4, 4, 1],
#        [5, 4, 1]], dtype=int32)

# %%
# 2. 使用 Pandas 创建一个Series对象，数据为[60, 20, 10, 40]，索引为['a', 'b', 'c', 'd']，然后获取索引为'b'的元素值
#    按照数据排序
a = pd.Series([60, 20, 10, 40],index=['a', 'b', 'c', 'd'])
a['b']
asort_a=a.sort_values()
asort_a
#
# Out:
# c    10
# b    20
# d    40
# a    60
# dtype: int64

# %%
# 3.创建一个dataframe  有name age列 birthday列 每一列有 3条数据
#   统计计算年龄的总和 平均数
#   获取出生日期的 年
#   获取出生日期的 月
#   获取出生日期的 日
#   获取出生日期的 统计周期月
#   获取的数据都添加到 df 内变为一列
#   将 name 列的名字改为 姓名 age--> 年龄
#   筛选出年龄>20的数据
df = pd.DataFrame({
    'name': ['张三', '李四', '王五'],
    'age': [25, 30, 18],
    'birthday': ['1998-05-12', '1993-10-25', '2005-03-07']
})
df['ymd']=pd.to_datetime(df['birthday'])


df
# Out:
#   name  age    birthday        ymd
# 0   张三   25  1998-05-12 1998-05-12
# 1   李四   30  1993-10-25 1993-10-25
# 2   王五   18  2005-03-07 2005-03-07

# %%
# 5.读取数据库中 员工表数据
#   获取 每一个部门的 男女员工的平均工资
#
from sqlalchemy import create_engine

engine = create_engine(
    f"mysql+pymysql://root:12345@localhost:3306/atguigu?charset=utf8mb4"
)
df1=pd.read_sql("select * from t_employee",con=engine)
df1
result=df1.groupby(['did','gender'])['salary'].mean().reset_index()
result
print(result)
# Out:
#    did gender   salary
# 0  1.0      女  12305.0
# 1  1.0      男  12116.0
# 2  2.0      女  18978.0
# 3  2.0      男   8978.0
# 4  3.0      女   9228.0
# 5  3.0      男  11488.5
# 6  4.0      女  12332.0
# 7  5.0      女  12443.0
# 8  5.0      男  10289.0
